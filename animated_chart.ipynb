# %%
# import numpy as np
import matplotlib.pyplot as plt
# from IPython.display import clear_output
import pandas as pd
import time

df = pd.DataFrame([ [1, 2], [3, 4], [0, .4], [.4, 0],[.2, 0]])

df = df.set_index([0])

for x in range(20):
  clear_output(wait=True)


  df.plot(grid=True,figsize=(16,5))
  plt.show() 
  time.sleep(.01)
  df=df.append(pd.Series([1, 2]), ignore_index=True)
